# %% [markdown]
# # Set paths using configuration files

# %%
import configparser

config_path = configparser.ConfigParser()
config_path.read('config_map.ini')

network_folder = config_path['NETWORKS']['network_folder']
contacts_folder = config_path['RAW_CONTACTS']['contacts_folder']

# %% [markdown]
# # Load the network

# %%
import os
import datetime as dt
import graph_tool.all as gt

network_file = 'gc_26.gml'
g = gt.load_graph(os.path.join(network_folder, network_file))
g_date = dt.date(2020, 4, 22)

# %%
# %reload_ext autoreload
# %autoreload 2
from lib.MapCore import MapCore

# %%
objmap = MapCore(g, date=g_date, contact_folder=contacts_folder, layers=5)
# Out:
# Memory warning: table of contacts consuming 3021.372212 MB of memory

# %%
# Initialize the map object using folium
from folium import Map

loc = (-3.775811, -38.530402) # FORTALEZA
m = Map(location=loc, zoom_start=12, max_zoom=17, min_zoom=7, tiles='openstreetmap')
objmap.initialize_map(m)

# %%
m, place_info = objmap.set_cores_on_map(start_core=5)
# Out:
# Number of components: 6

# %%
place_info['number_contacts'].sum()
# Out:
# 30689

# %%
network_file = 'gc_18.gml'
g = gt.load_graph(os.path.join(network_folder, network_file))
g_date = dt.date(2020, 4, 6)

# %%
objmap.change_network(g, g_date)

# %%
m, place_info = objmap.set_cores_on_map(start_core=5)
# Out:
# Number of components: 3

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
